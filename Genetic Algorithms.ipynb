# %%
#John Robinson
#CSC 462 artificial intelligence
#Homework Assignment #3: Genetic Algorithms
#10/1/21

# %%
import pandas as pd
import numpy as np
import random
import math

# %%
population = []

for q in range(0,18):
    population.append([random.uniform(.1, 1.0)])
    for w in range(0,32):
        population[q].append(random.uniform(.1, 1.0))

# %%
#print(population[1][0])
print(population)
# Out:
# [[0.35348603642165644, 0.7807926847048151, 0.2230063396532821, 0.438081287616516, 0.759795366671233, 0.5989143527596684, 0.285336233541151, 0.32826382191207604, 0.8431261653315658, 0.4603779673120547, 0.1309332307321628, 0.2591444910705111, 0.9397013049201219, 0.36262365530103546, 0.8817506436926724, 0.7455150008096435, 0.5166892547377943, 0.460936311130817, 0.7309129329293095, 0.6522783650760036, 0.945263583405818, 0.36341764871342785, 0.9647482213973999, 0.38070451103163216, 0.9787112421983273, 0.5054683476874884, 0.5046883001684621, 0.7504554753617936, 0.36633980353479034, 0.7779306230582735, 0.3150424864207644, 0.11177764452677708, 0.1675992710084609], [0.6877163438749573, 0.7438330778741192, 0.3291588774650418, 0.49154673404403004, 0.5457412109731213, 0.5769913562682699, 0.8501230188646556, 0.39253064136825033, 0.9513770464457147, 0.28776087713156134, 0.9527531890180759, 0.7604614828029467, 0.7877218311672811, 0.1845991288024316, 0.41871968917235314, 0.31533591507842207, 0.97749
# ...

# %%
#starting values
startx = 16
starty = 0
a = 0
x = startx
y = starty

# %%
for i in range(0,21):
    x = x + math.cos(i)
    y = y + math.sin(i)
    print(x)
    print(y)
# Out:
# 17.0
# 0.0
# 17.54030230586814
# 0.8414709848078965
# 17.124155469320996
# 1.7507684116335782
# 16.13416297272055
# 1.8918884196934453
# 15.480519351856938
# 1.1350859243855171
# 15.764181537320164
# 0.1761616497223787
# 16.72435182397053
# -0.10325384847654717
# 17.478254078313835
# 0.5537327502422419
# 17.332754044505222
# 1.5430909968656237
# 16.421623782620546
# 1.9552094821073802
# 15.582552253544094
# 1.4111883712180104
# 15.586977951532145
# 0.41119816466730696
# 16.430831910264637
# -0.12537475333312798
# 17.338278691714834
# 0.29479228349351294
# 17.475015909922668
# 1.2853996391883833
# 16.715327997063845
# 1.9356874793455001
# 15.75766851674046
# 1.6477841626804348
# 15.482505178688864
# 0.686386670800878
# 16.142821886932943
# -0.06460057597079816
# 17.131526505119613
# 0.08527663369215419
# 17.539608566933005
# 0.9982218844197819

# %%
random_number = random.randint(0, 2)
print(random_number)
# Out:
# 2

# %%
th = 0:pi/50:2*pi;
# Out:
#   File "<ipython-input-30-6aa32693f3e8>", line 1
#     th = 0:pi/50:2*pi;
#           ^
# SyntaxError: invalid syntax
